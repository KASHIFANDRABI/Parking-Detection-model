# %%
import os
from glob import glob
import pandas as pd
from functools import reduce
from xml.etree import ElementTree as et

# %%
xml_list = glob('./data_images/*.xml')
xml_list = list(map(lambda x: x.replace('\\','/'),xml_list))

# %%
xml_list
# Out:
# ['./data_images/102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.xml',
#  './data_images/132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.xml',
#  './data_images/142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.xml',
#  './data_images/183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.xml',
#  './data_images/202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.xml',
#  './data_images/218_jpg.rf.2e758b47a34c68ee81d26379969a614f.xml',
#  './data_images/234_jpg.rf.fefcb1b36f8cafb46ef5382c83099c1f.xml',
#  './data_images/243_jpg.rf.1adc6b9d548323a0c17e7c5900c43c93.xml',
#  './data_images/26_jpg.rf.2f74268b48670d805a1cfb0bf632487e.xml',
#  './data_images/281_jpg.rf.0891c6671bc9525ea47b7b2c77c4bb9f.xml',
#  './data_images/283_jpg.rf.7e83485981c4f84d50295d6374647778.xml',
#  './data_images/29_jpg.rf.edd6af188efea16ef9fc8b3ca4b6b191.xml',
#  './data_images/308_jpg.rf.978367edf8477f52fc7e21f3a71fd9f7.xml',
#  './data_images/311_jpg.rf.f3749846371efc78875c48362f9fc767.xml',
#  './data_images/321_jpg.rf.49c283be37e4ff9381e8ca3a1f79c0ec.xml',
#  './data_images/323_jpg.rf.b19e6f4bc57cfd91f00ed5a282f102be.xml',
#  './data_images/341_jpg.rf.6661ba01b0ccbb7222e78a77728b0901.xml',
#  './data_images/344_jpg.rf.3dd454545f5bb483e5b13fd1bdf2ecab.xml',
#  './data_images/358_jpg.rf.c85d06d365887070c5e96474839f4a21.xml',
#  './data_images/371_jpg.rf.3549457f59e2dcf0ed34310f9b971f6c.xml',
#  './data_images/374_jpg.rf.f427ebbf30a68c7a56324762a2ab33da.xml',
#  './data_images/387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.xml',
#  './data_images/390_jpg.rf.5506066f18275cc9dc24b1403447ae5d.xml',
#  './data_images/3_jpg.rf.7fa82209b5b67ff6796d90edb1b4e4ae.xml',
#  './data_images/407_jpg.rf.d8f7d7af0d65bb6d121c94ac142b2b17.xml',
#  './data_images/409_jpg.rf.bc22976e4930569f4d7e64e8e8d32b28.xml',
#  './data_images/414_jpg.rf.ce1c1dbd52cfd7930bf758a6cfc1c331.xml',
#  './data_images/419_jpg.rf.3ed23954e78b0a5e71676ea0d1db796c.xml',
#  './data_images/41_jpg.rf.6fca1e4f4b802520800ed19ea1dd8323.xml',
#  './data_images/420_jpg.rf.88a4dcbc660b4112322f098f62b25254.xml',
#  './data_images/446_jpg.rf.d4c0e5bc4676617eaf47ee90b70b968a.xml',
#  './data_images/46_jpg.rf.a769b760906743769118e3e8a6c5f7ab.xml',
#  './data_images/499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.xml',
#  './data_images/4_jpg.rf.fcaf9a6d943fab7ae1ce374cfa81f9a4.xml',
#  './data_images/510_jpg.rf.59f2277aa8093f2c3c5752d066651d46.xml',
#  './data_images/530_jpg.rf.1ed9fd0fcd84361238c4dd4f40a97e06.xml',
#  './data_images/538_jpg.rf.6b3fd00f5bc25f41077b888e9902521d.xml',
#  './data_images/553_jpg.rf.296382625cafab725c96e7d035bbd635.xml',
#  './data_images/56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.xml',
#  './data_images/579_jpg.rf.936413ef46da8a8ce2c5c993c075a72f.xml',
#  './data_images/57_jpg.rf.48a589ec39894c2309212c5af8f97527.xml',
#  './data_images/599_png.rf.353d179bc12d803ac0f8bd0f577daaca.xml',
#  './data_images/603_png.rf.8f6abd667a1a27155c280d3423d0b133.xml',
#  './data_images/60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.xml',
#  './data_images/610_png.rf.5360f879bdeb743ffc6b646e201c2a14.xml',
#  './data_images/621_png.rf.137b6574f94130acf71304b506030ea5.xml',
#  './data_images/623_png.rf.fc173486f03f565d8d681b27d5436ccf.xml',
#  './data_images/627_png.rf.cbad28c3955fb4c324d22d363bef7132.xml',
#  './data_images/631_png.rf.67aebef820f800867176eb670f562eff.xml',
#  './data_images/633_png.rf.06c53f1aff8ff479df88377797a78582.xml',
#  './data_images/637_png.rf.4e63ffcbbec334a87ea1955689cbbe88.xml',
#  './data_images/63_jpg.rf.7fbe2696ea93b89cd1ccbbc1fefb2ad6.xml',
#  './data_images/642_png.rf.f3685a347f3e1ab21c2e0821e1d2fa4f.xml',
#  './data_images/657_png.rf.3e06bce4e5c9d8615081d0493a658c3b.xml',
#  './data_images/663_png.rf.73399b52c9c035b2df7c077a7a55aa15.xml',
#  './data_images/678_png.rf.bedd4736a5036e46ecf3bf642ad608c6.xml',
#  './data_images/681_png.rf.0e9437d32e8ac036573cc675faa4a5d2.xml',
#  './data_images/687_png.rf.243d9cdea8c8735e723749ec9c888237.xml',
#  './data_images/698_png.rf.158fa91e79dbc2aaba8063363f34bac0.xml',
#  './data_images/75_jpg.rf.cceecffe658ad589ede21e3a17f69799.xml',
#  './data_images/82_jpg.rf.d04debcb84dd5b865797d3641770b90c.xml',
#  './data_images/85_jpg.rf.440b375112f0751aa4cd9de0a8435fbe.xml',
#  './data_images/89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.xml',
#  './data_images/96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.xml']

# %%
#Read xml file
#from each xml we need to extract
#filename,size(width, height), object(name,xmin,xmax,ymin,ymax)
#def extract_text(filename):
#    tree = et.parse(filename)
#   root = tree.getroot()
#    image_name = root.find('filename').text
#   #width & height of image
#    width = root.find('size').find('width').text
#    height = root.find('size').find('height').text
#    objs = root.findall('object')
#    parser = []
#    for obj in objs:
#        name = obj.find('name').text
#        bndbox = obj.find('bndbox')
#        xmin = bndbox.find('xmin').text
#        xmax = bndbox.find('xmax').text
#        ymin = bndbox.find('ymin').text
#        ymax = bndbox.find('ymax').text
#        parser.append([name,xmin,xmax,ymin,ymax])
#        
#    return parser

# %%
import os
import xml.etree.ElementTree as et

def extract_text(filename):
    """Extract information including width, height, and bounding boxes from a single XML file."""
    try:
        tree = et.parse(filename)
        root = tree.getroot()

        # Extract the image name from <filename>
        image_name_tag = root.find('filename')
        image_name = image_name_tag.text if image_name_tag is not None else "Unknown"
        
        # Extract width and height from the <size> tag
        size_tag = root.find('size')
        width = size_tag.find('width').text if size_tag is not None else "Unknown"
        height = size_tag.find('height').text if size_tag is not None else "Unknown"

        # Extract objects (bounding boxes and class IDs)
        objs = root.findall('object')
        parser = []
        for obj in objs:
            name = obj.find('name').text
            bndbox = obj.find('bndbox')
            xmin = bndbox.find('xmin').text
            xmax = bndbox.find('xmax').text
            ymin = bndbox.find('ymin').text
            ymax = bndbox.find('ymax').text

            # Append image name, width, height, and bounding box data
            parser.append([image_name, width, height, name, xmin, xmax, ymin, ymax])
        
        return parser
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        return None

def process_multiple_xml_files(directory):
    """Process all XML files in the given directory."""
    all_results = []

    # List all XML files in the directory
    xml_files = [f for f in os.listdir(directory) if f.endswith('.xml')]

['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg', '416', '416', '0', '54', '84', '109', '157']
# ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg', '416', '416', '0', '101', '144', '5', '97']
# ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg', '416', '416', '0', '81', '119', '2', '31']
# ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg', '416', '416', '0', '31', '54', '2', '23']
# ['96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg', '416', '416', '0', '196', '247', '3', '26']
# ['96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg', '416', '416', '0', '375', '416', '2', '22']

# %%
results_all = list(map(extract_text,xml_list))

# %%
data = reduce(lambda x,y : x+y,results_all)

# %%
data
# Out:
# [['102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg',
#   '416',
#   '416',
#   '0',
#   '188',
#   '234',
#   '4',
#   '28'],
#  ['102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg',
#   '416',
#   '416',
#   '0',
#   '367',
#   '416',
#   '4',
#   '27'],
#  ['102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg',
#   '416',
#   '416',
#   '0',
#   '379',
#   '417',
#   '49',
#   '88'],
#  ['132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg',
#   '416',
#   '416',
#   '0',
#   '175',
#   '246',
#   '5',
#   '60'],
#  ['132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg',
#   '416',
#   '416',
#   '0',
#   '227',
#   '342',
#   '91',
#   '197'],
#  ['142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg',
#   '416',
#   '416',
#   '3',
#   '171',
#   '416',
#   '1',
#   '60'],
#  ['142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg',
#   '416',
#   '416',
#   '0',
#   '40',
#   '95',
#   '1',
#   '33'],
#  ['142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg',
#   '416',
#   '416',
#   '0',
#   '107',
#   '165',
#   '2',
#   '23'],
#  ['183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg',
#   '416',
#   '416',
#   '0',
#   '203',
#   '248',
#   '20',
#   '46'],
#  ['183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg',
#   '416',
#   '416',
#   '0',
#   '357',
#   '417',
#   '122',
#   '184'],
#  ['183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg',
#   '416',
#   '416',
#   '0',
#   '256',
#   '292',
#   '1',
#   '16'],
#  ['183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg',
#   '416',
#   '416',
#   '1',
#   '282',
#   '296',
#   '14',
#   '36'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '317',
#   '364',
#   '15',
#   '39'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '240',
#   '295',
#   '39',
#   '70'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '260',
#   '300',
#   '9',
#   '30'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '358',
#   '415',
#   '54',
#   '92'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '382',
#   '416',
#   '88',
#   '134'],
#  ['202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg',
#   '416',
#   '416',
#   '0',
#   '277',
#   '407',
#   '141',
#   '220'],
#  ['218_jpg.rf.2e758b47a34c68ee81d26379969a614f.jpg',
#   '416',
#   '416',
#   '0',
#   '116',
#   '168',
#   '8',
#   '37'],
#  ['234_jpg.rf.fefcb1b36f8cafb46ef5382c83099c1f.jpg',
#   '416',
#   '416',
#   '0',
#   '86',
#   '185',
#   '237',
#   '417'],
#  ['234_jpg.rf.fefcb1b36f8cafb46ef5382c83099c1f.jpg',
#   '416',
#   '416',
#   '0',
#   '212',
#   '250',
#   '2',
#   '50'],
#  ['243_jpg.rf.1adc6b9d548323a0c17e7c5900c43c93.jpg',
#   '416',
#   '416',
#   '0',
#   '364',
#   '417',
#   '2',
#   '23'],
#  ['243_jpg.rf.1adc6b9d548323a0c17e7c5900c43c93.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '28',
#   '89',
#   '146'],
#  ['26_jpg.rf.2f74268b48670d805a1cfb0bf632487e.jpg',
#   '416',
#   '416',
#   '0',
#   '328',
#   '379',
#   '10',
#   '35'],
#  ['26_jpg.rf.2f74268b48670d805a1cfb0bf632487e.jpg',
#   '416',
#   '416',
#   '0',
#   '362',
#   '417',
#   '37',
#   '67'],
#  ['26_jpg.rf.2f74268b48670d805a1cfb0bf632487e.jpg',
#   '416',
#   '416',
#   '0',
#   '336',
#   '406',
#   '60',
#   '100'],
#  ['26_jpg.rf.2f74268b48670d805a1cfb0bf632487e.jpg',
#   '416',
#   '416',
#   '0',
#   '294',
#   '416',
#   '136',
#   '207'],
#  ['281_jpg.rf.0891c6671bc9525ea47b7b2c77c4bb9f.jpg',
#   '416',
#   '416',
#   '0',
#   '252',
#   '299',
#   '29',
#   '56'],
#  ['281_jpg.rf.0891c6671bc9525ea47b7b2c77c4bb9f.jpg',
#   '416',
#   '416',
#   '0',
#   '172',
#   '240',
#   '74',
#   '123'],
#  ['281_jpg.rf.0891c6671bc9525ea47b7b2c77c4bb9f.jpg',
#   '416',
#   '416',
#   '0',
#   '327',
#   '416',
#   '95',
#   '153'],
#  ['283_jpg.rf.7e83485981c4f84d50295d6374647778.jpg',
#   '416',
#   '416',
#   '0',
#   '169',
#   '239',
#   '32',
#   '78'],
#  ['283_jpg.rf.7e83485981c4f84d50295d6374647778.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '75',
#   '87',
#   '145'],
#  ['29_jpg.rf.edd6af188efea16ef9fc8b3ca4b6b191.jpg',
#   '416',
#   '416',
#   '0',
#   '114',
#   '231',
#   '79',
#   '165'],
#  ['308_jpg.rf.978367edf8477f52fc7e21f3a71fd9f7.jpg',
#   '416',
#   '416',
#   '0',
#   '277',
#   '335',
#   '103',
#   '219'],
#  ['308_jpg.rf.978367edf8477f52fc7e21f3a71fd9f7.jpg',
#   '416',
#   '416',
#   '0',
#   '368',
#   '416',
#   '189',
#   '331'],
#  ['311_jpg.rf.f3749846371efc78875c48362f9fc767.jpg',
#   '416',
#   '416',
#   '1',
#   '323',
#   '355',
#   '21',
#   '59'],
#  ['311_jpg.rf.f3749846371efc78875c48362f9fc767.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '72',
#   '106',
#   '186'],
#  ['321_jpg.rf.49c283be37e4ff9381e8ca3a1f79c0ec.jpg',
#   '416',
#   '416',
#   '0',
#   '30',
#   '97',
#   '1',
#   '29'],
#  ['321_jpg.rf.49c283be37e4ff9381e8ca3a1f79c0ec.jpg',
#   '416',
#   '416',
#   '3',
#   '302',
#   '416',
#   '1',
#   '89'],
#  ['323_jpg.rf.b19e6f4bc57cfd91f00ed5a282f102be.jpg',
#   '416',
#   '416',
#   '0',
#   '248',
#   '354',
#   '112',
#   '320'],
#  ['341_jpg.rf.6661ba01b0ccbb7222e78a77728b0901.jpg',
#   '416',
#   '416',
#   '0',
#   '334',
#   '373',
#   '4',
#   '49'],
#  ['341_jpg.rf.6661ba01b0ccbb7222e78a77728b0901.jpg',
#   '416',
#   '416',
#   '4',
#   '355',
#   '381',
#   '135',
#   '227'],
#  ['341_jpg.rf.6661ba01b0ccbb7222e78a77728b0901.jpg',
#   '416',
#   '416',
#   '0',
#   '186',
#   '214',
#   '1',
#   '20'],
#  ['344_jpg.rf.3dd454545f5bb483e5b13fd1bdf2ecab.jpg',
#   '416',
#   '416',
#   '0',
#   '182',
#   '295',
#   '86',
#   '177'],
#  ['358_jpg.rf.c85d06d365887070c5e96474839f4a21.jpg',
#   '416',
#   '416',
#   '0',
#   '369',
#   '416',
#   '29',
#   '85'],
#  ['371_jpg.rf.3549457f59e2dcf0ed34310f9b971f6c.jpg',
#   '416',
#   '416',
#   '0',
#   '310',
#   '374',
#   '33',
#   '79'],
#  ['371_jpg.rf.3549457f59e2dcf0ed34310f9b971f6c.jpg',
#   '416',
#   '416',
#   '0',
#   '309',
#   '365',
#   '9',
#   '22'],
#  ['371_jpg.rf.3549457f59e2dcf0ed34310f9b971f6c.jpg',
#   '416',
#   '416',
#   '0',
#   '399',
#   '416',
#   '55',
#   '75'],
#  ['374_jpg.rf.f427ebbf30a68c7a56324762a2ab33da.jpg',
#   '416',
#   '416',
#   '0',
#   '127',
#   '193',
#   '28',
#   '78'],
#  ['387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.jpg',
#   '416',
#   '416',
#   '0',
#   '87',
#   '125',
#   '13',
#   '34'],
#  ['387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.jpg',
#   '416',
#   '416',
#   '0',
#   '168',
#   '211',
#   '20',
#   '44'],
#  ['387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.jpg',
#   '416',
#   '416',
#   '0',
#   '122',
#   '173',
#   '33',
#   '65'],
#  ['387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.jpg',
#   '416',
#   '416',
#   '0',
#   '190',
#   '263',
#   '65',
#   '111'],
#  ['387_jpg.rf.56ae7e9bb7dbdb0cfb1df2d1e919d657.jpg',
#   '416',
#   '416',
#   '1',
#   '50',
#   '80',
#   '57',
#   '95'],
#  ['390_jpg.rf.5506066f18275cc9dc24b1403447ae5d.jpg',
#   '416',
#   '416',
#   '1',
#   '230',
#   '258',
#   '41',
#   '82'],
#  ['390_jpg.rf.5506066f18275cc9dc24b1403447ae5d.jpg',
#   '416',
#   '416',
#   '1',
#   '63',
#   '108',
#   '117',
#   '179'],
#  ['390_jpg.rf.5506066f18275cc9dc24b1403447ae5d.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '28',
#   '124',
#   '190'],
#  ['3_jpg.rf.7fa82209b5b67ff6796d90edb1b4e4ae.jpg',
#   '416',
#   '416',
#   '0',
#   '249',
#   '350',
#   '107',
#   '168'],
#  ['407_jpg.rf.d8f7d7af0d65bb6d121c94ac142b2b17.jpg',
#   '416',
#   '416',
#   '0',
#   '289',
#   '353',
#   '8',
#   '56'],
#  ['407_jpg.rf.d8f7d7af0d65bb6d121c94ac142b2b17.jpg',
#   '416',
#   '416',
#   '0',
#   '192',
#   '253',
#   '1',
#   '31'],
#  ['407_jpg.rf.d8f7d7af0d65bb6d121c94ac142b2b17.jpg',
#   '416',
#   '416',
#   '0',
#   '306',
#   '416',
#   '126',
#   '242'],
#  ['407_jpg.rf.d8f7d7af0d65bb6d121c94ac142b2b17.jpg',
#   '416',
#   '416',
#   '2',
#   '1',
#   '179',
#   '146',
#   '341'],
#  ['409_jpg.rf.bc22976e4930569f4d7e64e8e8d32b28.jpg',
#   '416',
#   '416',
#   '0',
#   '195',
#   '277',
#   '81',
#   '134'],
#  ['409_jpg.rf.bc22976e4930569f4d7e64e8e8d32b28.jpg',
#   '416',
#   '416',
#   '0',
#   '226',
#   '263',
#   '6',
#   '27'],
#  ['409_jpg.rf.bc22976e4930569f4d7e64e8e8d32b28.jpg',
#   '416',
#   '416',
#   '0',
#   '247',
#   '282',
#   '1',
#   '14'],
#  ['409_jpg.rf.bc22976e4930569f4d7e64e8e8d32b28.jpg',
#   '416',
#   '416',
#   '3',
#   '1',
#   '249',
#   '27',
#   '190'],
#  ['414_jpg.rf.ce1c1dbd52cfd7930bf758a6cfc1c331.jpg',
#   '416',
#   '416',
#   '0',
#   '312',
#   '401',
#   '28',
#   '97'],
#  ['414_jpg.rf.ce1c1dbd52cfd7930bf758a6cfc1c331.jpg',
#   '416',
#   '416',
#   '0',
#   '258',
#   '311',
#   '1',
#   '14'],
#  ['414_jpg.rf.ce1c1dbd52cfd7930bf758a6cfc1c331.jpg',
#   '416',
#   '416',
#   '0',
#   '117',
#   '197',
#   '25',
#   '52'],
#  ['414_jpg.rf.ce1c1dbd52cfd7930bf758a6cfc1c331.jpg',
#   '416',
#   '416',
#   '3',
#   '1',
#   '240',
#   '46',
#   '344'],
#  ['419_jpg.rf.3ed23954e78b0a5e71676ea0d1db796c.jpg',
#   '416',
#   '416',
#   '0',
#   '277',
#   '349',
#   '1',
#   '50'],
#  ['419_jpg.rf.3ed23954e78b0a5e71676ea0d1db796c.jpg',
#   '416',
#   '416',
#   '0',
#   '121',
#   '210',
#   '1',
#   '60'],
#  ['41_jpg.rf.6fca1e4f4b802520800ed19ea1dd8323.jpg',
#   '416',
#   '416',
#   '0',
#   '25',
#   '114',
#   '36',
#   '92'],
#  ['41_jpg.rf.6fca1e4f4b802520800ed19ea1dd8323.jpg',
#   '416',
#   '416',
#   '0',
#   '357',
#   '416',
#   '30',
#   '89'],
#  ['41_jpg.rf.6fca1e4f4b802520800ed19ea1dd8323.jpg',
#   '416',
#   '416',
#   '0',
#   '168',
#   '224',
#   '2',
#   '22'],
#  ['420_jpg.rf.88a4dcbc660b4112322f098f62b25254.jpg',
#   '416',
#   '416',
#   '0',
#   '147',
#   '242',
#   '2',
#   '59'],
#  ['420_jpg.rf.88a4dcbc660b4112322f098f62b25254.jpg',
#   '416',
#   '416',
#   '0',
#   '83',
#   '147',
#   '1',
#   '16'],
#  ['420_jpg.rf.88a4dcbc660b4112322f098f62b25254.jpg',
#   '416',
#   '416',
#   '0',
#   '157',
#   '288',
#   '80',
#   '206'],
#  ['420_jpg.rf.88a4dcbc660b4112322f098f62b25254.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '86',
#   '264',
#   '312'],
#  ['446_jpg.rf.d4c0e5bc4676617eaf47ee90b70b968a.jpg',
#   '416',
#   '416',
#   '0',
#   '75',
#   '113',
#   '48',
#   '110'],
#  ['446_jpg.rf.d4c0e5bc4676617eaf47ee90b70b968a.jpg',
#   '416',
#   '416',
#   '0',
#   '264',
#   '299',
#   '9',
#   '55'],
#  ['446_jpg.rf.d4c0e5bc4676617eaf47ee90b70b968a.jpg',
#   '416',
#   '416',
#   '0',
#   '226',
#   '252',
#   '1',
#   '27'],
#  ['446_jpg.rf.d4c0e5bc4676617eaf47ee90b70b968a.jpg',
#   '416',
#   '416',
#   '1',
#   '336',
#   '358',
#   '107',
#   '178'],
#  ['46_jpg.rf.a769b760906743769118e3e8a6c5f7ab.jpg',
#   '416',
#   '416',
#   '0',
#   '69',
#   '129',
#   '3',
#   '34'],
#  ['46_jpg.rf.a769b760906743769118e3e8a6c5f7ab.jpg',
#   '416',
#   '416',
#   '0',
#   '122',
#   '215',
#   '43',
#   '105'],
#  ['46_jpg.rf.a769b760906743769118e3e8a6c5f7ab.jpg',
#   '416',
#   '416',
#   '0',
#   '365',
#   '416',
#   '192',
#   '400'],
#  ['499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.jpg',
#   '416',
#   '416',
#   '3',
#   '131',
#   '321',
#   '50',
#   '109'],
#  ['499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.jpg',
#   '416',
#   '416',
#   '0',
#   '128',
#   '169',
#   '37',
#   '49'],
#  ['499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.jpg',
#   '416',
#   '416',
#   '0',
#   '21',
#   '113',
#   '102',
#   '136'],
#  ['499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.jpg',
#   '416',
#   '416',
#   '0',
#   '387',
#   '416',
#   '104',
#   '125'],
#  ['499_jpg.rf.e9ec2aec3060dea46de9b7bb191073e5.jpg',
#   '416',
#   '416',
#   '0',
#   '390',
#   '416',
#   '125',
#   '147'],
#  ['4_jpg.rf.fcaf9a6d943fab7ae1ce374cfa81f9a4.jpg',
#   '416',
#   '416',
#   '0',
#   '244',
#   '319',
#   '73',
#   '117'],
#  ['510_jpg.rf.59f2277aa8093f2c3c5752d066651d46.jpg',
#   '416',
#   '416',
#   '1',
#   '152',
#   '179',
#   '47',
#   '82'],
#  ['510_jpg.rf.59f2277aa8093f2c3c5752d066651d46.jpg',
#   '416',
#   '416',
#   '0',
#   '286',
#   '360',
#   '64',
#   '108'],
#  ['530_jpg.rf.1ed9fd0fcd84361238c4dd4f40a97e06.jpg',
#   '416',
#   '416',
#   '0',
#   '128',
#   '172',
#   '17',
#   '41'],
#  ['530_jpg.rf.1ed9fd0fcd84361238c4dd4f40a97e06.jpg',
#   '416',
#   '416',
#   '0',
#   '213',
#   '262',
#   '21',
#   '48'],
#  ['530_jpg.rf.1ed9fd0fcd84361238c4dd4f40a97e06.jpg',
#   '416',
#   '416',
#   '0',
#   '298',
#   '399',
#   '79',
#   '129'],
#  ['530_jpg.rf.1ed9fd0fcd84361238c4dd4f40a97e06.jpg',
#   '416',
#   '416',
#   '1',
#   '342',
#   '367',
#   '37',
#   '69'],
#  ['538_jpg.rf.6b3fd00f5bc25f41077b888e9902521d.jpg',
#   '416',
#   '416',
#   '0',
#   '293',
#   '332',
#   '1',
#   '10'],
#  ['538_jpg.rf.6b3fd00f5bc25f41077b888e9902521d.jpg',
#   '416',
#   '416',
#   '3',
#   '1',
#   '214',
#   '86',
#   '327'],
#  ['553_jpg.rf.296382625cafab725c96e7d035bbd635.jpg',
#   '416',
#   '416',
#   '0',
#   '108',
#   '171',
#   '17',
#   '57'],
#  ['553_jpg.rf.296382625cafab725c96e7d035bbd635.jpg',
#   '416',
#   '416',
#   '0',
#   '215',
#   '273',
#   '1',
#   '27'],
#  ['553_jpg.rf.296382625cafab725c96e7d035bbd635.jpg',
#   '416',
#   '416',
#   '0',
#   '372',
#   '416',
#   '121',
#   '178'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '0',
#   '67',
#   '146',
#   '70',
#   '119'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '0',
#   '46',
#   '99',
#   '18',
#   '47'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '0',
#   '127',
#   '168',
#   '4',
#   '28'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '0',
#   '301',
#   '347',
#   '15',
#   '38'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '0',
#   '334',
#   '402',
#   '39',
#   '69'],
#  ['56_jpg.rf.fccfd295f1ec07ee02ff68f54b6f5382.jpg',
#   '416',
#   '416',
#   '3',
#   '170',
#   '389',
#   '1',
#   '148'],
#  ['579_jpg.rf.936413ef46da8a8ce2c5c993c075a72f.jpg',
#   '416',
#   '416',
#   '2',
#   '184',
#   '315',
#   '1',
#   '52'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '81',
#   '128',
#   '26',
#   '49'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '88',
#   '160',
#   '64',
#   '105'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '152',
#   '186',
#   '12',
#   '31'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '277',
#   '312',
#   '6',
#   '21'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '316',
#   '364',
#   '30',
#   '53'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '311',
#   '353',
#   '18',
#   '35'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '350',
#   '416',
#   '54',
#   '81'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '0',
#   '339',
#   '400',
#   '71',
#   '108'],
#  ['57_jpg.rf.48a589ec39894c2309212c5af8f97527.jpg',
#   '416',
#   '416',
#   '3',
#   '189',
#   '340',
#   '6',
#   '121'],
#  ['599_png.rf.353d179bc12d803ac0f8bd0f577daaca.jpg',
#   '416',
#   '416',
#   '0',
#   '318',
#   '356',
#   '157',
#   '223'],
#  ['599_png.rf.353d179bc12d803ac0f8bd0f577daaca.jpg',
#   '416',
#   '416',
#   '0',
#   '251',
#   '308',
#   '176',
#   '247'],
#  ['599_png.rf.353d179bc12d803ac0f8bd0f577daaca.jpg',
#   '416',
#   '416',
#   '0',
#   '379',
#   '401',
#   '174',
#   '199'],
#  ['599_png.rf.353d179bc12d803ac0f8bd0f577daaca.jpg',
#   '416',
#   '416',
#   '0',
#   '355',
#   '380',
#   '166',
#   '208'],
#  ['599_png.rf.353d179bc12d803ac0f8bd0f577daaca.jpg',
#   '416',
#   '416',
#   '0',
#   '233',
#   '270',
#   '161',
#   '218'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '273',
#   '363',
#   '138',
#   '267'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '191',
#   '275',
#   '127',
#   '217'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '2',
#   '104',
#   '117',
#   '244'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '42',
#   '151',
#   '319'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '373',
#   '416',
#   '127',
#   '185'],
#  ['603_png.rf.8f6abd667a1a27155c280d3423d0b133.jpg',
#   '416',
#   '416',
#   '0',
#   '322',
#   '374',
#   '134',
#   '207'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '154',
#   '188',
#   '11',
#   '24'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '149',
#   '197',
#   '30',
#   '55'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '204',
#   '231',
#   '2',
#   '12'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '299',
#   '321',
#   '1',
#   '8'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '319',
#   '353',
#   '7',
#   '21'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '359',
#   '409',
#   '29',
#   '52'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '347',
#   '394',
#   '19',
#   '35'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '392',
#   '417',
#   '54',
#   '71'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '371',
#   '416',
#   '71',
#   '110'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '3',
#   '233',
#   '303',
#   '2',
#   '60'],
#  ['60_jpg.rf.bc3d0627dc7a27d9330de5351b70a96a.jpg',
#   '416',
#   '416',
#   '0',
#   '164',
#   '308',
#   '160',
#   '254'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '3',
#   '140',
#   '115',
#   '334'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '258',
#   '311',
#   '120',
#   '197'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '330',
#   '371',
#   '124',
#   '181'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '233',
#   '263',
#   '121',
#   '180'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '383',
#   '402',
#   '121',
#   '149'],
#  ['610_png.rf.5360f879bdeb743ffc6b646e201c2a14.jpg',
#   '416',
#   '416',
#   '0',
#   '410',
#   '416',
#   '122',
#   '149'],
#  ['621_png.rf.137b6574f94130acf71304b506030ea5.jpg',
#   '416',
#   '416',
#   '0',
#   '214',
#   '296',
#   '147',
#   '255'],
#  ['621_png.rf.137b6574f94130acf71304b506030ea5.jpg',
#   '416',
#   '416',
#   '0',
#   '307',
#   '358',
#   '169',
#   '241'],
#  ['621_png.rf.137b6574f94130acf71304b506030ea5.jpg',
#   '416',
#   '416',
#   '0',
#   '392',
#   '414',
#   '168',
#   '206'],
#  ['621_png.rf.137b6574f94130acf71304b506030ea5.jpg',
#   '416',
#   '416',
#   '0',
#   '283',
#   '314',
#   '163',
#   '204'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '0',
#   '38',
#   '135',
#   '175',
#   '292'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '0',
#   '205',
#   '253',
#   '184',
#   '246'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '0',
#   '308',
#   '336',
#   '192',
#   '249'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '2',
#   '256',
#   '310',
#   '137',
#   '257'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '0',
#   '329',
#   '351',
#   '187',
#   '220'],
#  ['623_png.rf.fc173486f03f565d8d681b27d5436ccf.jpg',
#   '416',
#   '416',
#   '1',
#   '356',
#   '370',
#   '193',
#   '264'],
#  ['627_png.rf.cbad28c3955fb4c324d22d363bef7132.jpg',
#   '416',
#   '416',
#   '0',
#   '104',
#   '180',
#   '10',
#   '105'],
#  ['631_png.rf.67aebef820f800867176eb670f562eff.jpg',
#   '416',
#   '416',
#   '0',
#   '197',
#   '327',
#   '128',
#   '296'],
#  ['631_png.rf.67aebef820f800867176eb670f562eff.jpg',
#   '416',
#   '416',
#   '0',
#   '102',
#   '201',
#   '115',
#   '241'],
#  ['631_png.rf.67aebef820f800867176eb670f562eff.jpg',
#   '416',
#   '416',
#   '0',
#   '311',
#   '355',
#   '121',
#   '185'],
#  ['631_png.rf.67aebef820f800867176eb670f562eff.jpg',
#   '416',
#   '416',
#   '0',
#   '361',
#   '406',
#   '121',
#   '180'],
#  ['631_png.rf.67aebef820f800867176eb670f562eff.jpg',
#   '416',
#   '416',
#   '0',
#   '402',
#   '416',
#   '117',
#   '148'],
#  ['633_png.rf.06c53f1aff8ff479df88377797a78582.jpg',
#   '416',
#   '416',
#   '0',
#   '305',
#   '371',
#   '103',
#   '196'],
#  ['633_png.rf.06c53f1aff8ff479df88377797a78582.jpg',
#   '416',
#   '416',
#   '0',
#   '359',
#   '405',
#   '107',
#   '178'],
#  ['633_png.rf.06c53f1aff8ff479df88377797a78582.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '89',
#   '109',
#   '369'],
#  ['633_png.rf.06c53f1aff8ff479df88377797a78582.jpg',
#   '416',
#   '416',
#   '0',
#   '18',
#   '68',
#   '101',
#   '205'],
#  ['637_png.rf.4e63ffcbbec334a87ea1955689cbbe88.jpg',
#   '416',
#   '416',
#   '0',
#   '96',
#   '235',
#   '21',
#   '206'],
#  ['63_jpg.rf.7fbe2696ea93b89cd1ccbbc1fefb2ad6.jpg',
#   '416',
#   '416',
#   '0',
#   '169',
#   '232',
#   '36',
#   '70'],
#  ['63_jpg.rf.7fbe2696ea93b89cd1ccbbc1fefb2ad6.jpg',
#   '416',
#   '416',
#   '0',
#   '368',
#   '416',
#   '9',
#   '35'],
#  ['63_jpg.rf.7fbe2696ea93b89cd1ccbbc1fefb2ad6.jpg',
#   '416',
#   '416',
#   '3',
#   '276',
#   '416',
#   '37',
#   '210'],
#  ['642_png.rf.f3685a347f3e1ab21c2e0821e1d2fa4f.jpg',
#   '416',
#   '416',
#   '0',
#   '23',
#   '260',
#   '139',
#   '403'],
#  ['642_png.rf.f3685a347f3e1ab21c2e0821e1d2fa4f.jpg',
#   '416',
#   '416',
#   '0',
#   '205',
#   '267',
#   '132',
#   '211'],
#  ['642_png.rf.f3685a347f3e1ab21c2e0821e1d2fa4f.jpg',
#   '416',
#   '416',
#   '0',
#   '342',
#   '407',
#   '136',
#   '228'],
#  ['657_png.rf.3e06bce4e5c9d8615081d0493a658c3b.jpg',
#   '416',
#   '416',
#   '0',
#   '146',
#   '298',
#   '245',
#   '416'],
#  ['657_png.rf.3e06bce4e5c9d8615081d0493a658c3b.jpg',
#   '416',
#   '416',
#   '0',
#   '207',
#   '307',
#   '46',
#   '210'],
#  ['657_png.rf.3e06bce4e5c9d8615081d0493a658c3b.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '79',
#   '24',
#   '195'],
#  ['663_png.rf.73399b52c9c035b2df7c077a7a55aa15.jpg',
#   '416',
#   '416',
#   '0',
#   '130',
#   '204',
#   '1',
#   '70'],
#  ['678_png.rf.bedd4736a5036e46ecf3bf642ad608c6.jpg',
#   '416',
#   '416',
#   '0',
#   '187',
#   '307',
#   '58',
#   '265'],
#  ['678_png.rf.bedd4736a5036e46ecf3bf642ad608c6.jpg',
#   '416',
#   '416',
#   '0',
#   '195',
#   '280',
#   '3',
#   '58'],
#  ['678_png.rf.bedd4736a5036e46ecf3bf642ad608c6.jpg',
#   '416',
#   '416',
#   '0',
#   '24',
#   '100',
#   '1',
#   '82'],
#  ['678_png.rf.bedd4736a5036e46ecf3bf642ad608c6.jpg',
#   '416',
#   '416',
#   '0',
#   '1',
#   '65',
#   '135',
#   '378'],
#  ['681_png.rf.0e9437d32e8ac036573cc675faa4a5d2.jpg',
#   '416',
#   '416',
#   '0',
#   '179',
#   '328',
#   '190',
#   '415'],
#  ['681_png.rf.0e9437d32e8ac036573cc675faa4a5d2.jpg',
#   '416',
#   '416',
#   '0',
#   '29',
#   '97',
#   '4',
#   '47'],
#  ['681_png.rf.0e9437d32e8ac036573cc675faa4a5d2.jpg',
#   '416',
#   '416',
#   '0',
#   '171',
#   '244',
#   '1',
#   '60'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '13',
#   '131',
#   '124',
#   '309'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '62',
#   '147',
#   '120',
#   '216'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '256',
#   '344',
#   '135',
#   '251'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '317',
#   '368',
#   '136',
#   '218'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '378',
#   '416',
#   '134',
#   '194'],
#  ['687_png.rf.243d9cdea8c8735e723749ec9c888237.jpg',
#   '416',
#   '416',
#   '0',
#   '366',
#   '389',
#   '127',
#   '172'],
#  ['698_png.rf.158fa91e79dbc2aaba8063363f34bac0.jpg',
#   '416',
#   '416',
#   '0',
#   '3',
#   '53',
#   '132',
#   '202'],
#  ['698_png.rf.158fa91e79dbc2aaba8063363f34bac0.jpg',
#   '416',
#   '416',
#   '2',
#   '28',
#   '82',
#   '62',
#   '180'],
#  ['75_jpg.rf.cceecffe658ad589ede21e3a17f69799.jpg',
#   '416',
#   '416',
#   '0',
#   '381',
#   '417',
#   '24',
#   '46'],
#  ['75_jpg.rf.cceecffe658ad589ede21e3a17f69799.jpg',
#   '416',
#   '416',
#   '0',
#   '339',
#   '374',
#   '2',
#   '16'],
#  ['82_jpg.rf.d04debcb84dd5b865797d3641770b90c.jpg',
#   '416',
#   '416',
#   '0',
#   '87',
#   '188',
#   '58',
#   '135'],
#  ['82_jpg.rf.d04debcb84dd5b865797d3641770b90c.jpg',
#   '416',
#   '416',
#   '0',
#   '63',
#   '111',
#   '2',
#   '16'],
#  ['85_jpg.rf.440b375112f0751aa4cd9de0a8435fbe.jpg',
#   '416',
#   '416',
#   '0',
#   '34',
#   '115',
#   '32',
#   '90'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '53',
#   '82',
#   '231',
#   '289'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '17',
#   '40',
#   '179',
#   '222'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '11',
#   '31',
#   '118',
#   '152'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '54',
#   '84',
#   '109',
#   '157'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '101',
#   '144',
#   '5',
#   '97'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '81',
#   '119',
#   '2',
#   '31'],
#  ['89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg',
#   '416',
#   '416',
#   '0',
#   '31',
#   '54',
#   '2',
#   '23'],
#  ['96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg',
#   '416',
#   '416',
#   '0',
#   '196',
#   '247',
#   '3',
#   '26'],
#  ['96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg',
#   '416',
#   '416',
#   '0',
#   '375',
#   '416',
#   '2',
#   '22']]

# %%
df = pd.DataFrame(data,columns = ['Filename','Width', 'Height','Name', 'xmin', 'xmax', 'ymin', 'ymax'])

# %%
df
# Out:
#                                             Filename Width Height Name xmin  \
# 0    102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg   416    416    0  188
# 1    102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg   416    416    0  367
# 2    102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg   416    416    0  379
# 3    132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg   416    416    0  175
# 4    132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg   416    416    0  227
# ..                                               ...   ...    ...  ...  ...
# 202   89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg   416    416    0  101
# 203   89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg   416    416    0   81
# 204   89_jpg.rf.c65677ca51bbe9f57e3b87ece1462272.jpg   416    416    0   31
# 205   96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg   416    416    0  196
# 206   96_jpg.rf.b050c48a3839f4e1caa5d441fd6d88b8.jpg   416    416    0  375
#
#     xmax ymin ymax
# 0    234    4   28
# 1    416    4   27
# 2    417   49   88
# 3    246    5   60
# 4    342   91  197
# ..   ...  ...  ...
# 202  144    5   97
# 203  119    2   31
# 204   54    2   23
# 205  247    3   26
# 206  416    2   22
#
# [207 rows x 8 columns]

# %%
df.shape
# Out:
# (207, 8)

# %%
df["Name"].value_counts()
# Out:
# Name
# 0    183
# 3     10
# 1      9
# 2      4
# 4      1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filename  207 non-null    object
#  1   Width     207 non-null    object
#  2   Height    207 non-null    object
#  3   Name      207 non-null    object
#  4   xmin      207 non-null    object
#  5   xmax      207 non-null    object
#  6   ymin      207 non-null    object
#  7   ymax      207 non-null    object
# dtypes: object(8)
# memory usage: 13.1+ KB

# %%
#type conversion
cols = ['Width','Height','xmin','xmax','ymin','ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filename  207 non-null    object
#  1   Width     207 non-null    int64
#  2   Height    207 non-null    int64
#  3   Name      207 non-null    object
#  4   xmin      207 non-null    int64
#  5   xmax      207 non-null    int64
#  6   ymin      207 non-null    int64
#  7   ymax      207 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 13.1+ KB

# %%
#center x, center y
df['center_x'] = ((df['xmax'] + df['xmin'])/2)/df['Width']
df['center_y'] = ((df['ymax'] + df['ymin'])/2)/df['Height']

#w
df['w'] = (df['xmax']-df['xmin'])/df['Width']

#h
df['h'] = (df['ymax']-df['ymin'])/df['Height']

# %%
df.head()
# Out:
#                                           Filename  Width  Height Name  xmin  \
# 0  102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   188
# 1  102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   367
# 2  102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   379
# 3  132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   175
# 4  132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   227
#
#    xmax  ymin  ymax  center_x  center_y         w         h
# 0   234     4    28  0.507212  0.038462  0.110577  0.057692
# 1   416     4    27  0.941106  0.037260  0.117788  0.055288
# 2   417    49    88  0.956731  0.164663  0.091346  0.093750
# 3   246     5    60  0.506010  0.078125  0.170673  0.132212
# 4   342    91   197  0.683894  0.346154  0.276442  0.254808

# %% [markdown]
# Split data Into Train And Test

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.5.2

# %%
images = df['Filename'].unique()

# %%
len(images)
# Out:
# 64

# %%
from sklearn.model_selection import train_test_split

# Assume df is your DataFrame and it has a 'Filename' column
# Example DataFrame creation (you should replace this with your actual DataFrame)
# df = pd.read_csv('your_data.csv') # Load your DataFrame if needed

# Split the filenames into train and test sets
train_filenames, test_filenames = train_test_split(df['Filename'].unique(), test_size=0.2, random_state=42)

# Create training DataFrame
train_df = df[df['Filename'].isin(train_filenames)]

# Create testing DataFrame
test_df = df[df['Filename'].isin(test_filenames)]

# Output the shapes of the resulting DataFrames
print(f"Train Set: {train_df.shape}")  # Print number of rows and columns for train set
print(f"Test Set: {test_df.shape}")    # Print number of rows and columns for test set
# Out:
# Train Set: (165, 12)
# Test Set: (42, 12)

# %%
# Shuffle DataFrame rows
#df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# Define split ratio
#split_ratio = 0.8
#split_index = int(len(df) * split_ratio)

# Split DataFrame into training and testing sets
#train_df = df.iloc[:split_index]
#test_df = df.iloc[split_index:]

# Output the shapes of the resulting DataFrames
#print(f"Train Set: {train_df.shape}")  # Print number of rows and columns for train set
#print(f"Test Set: {test_df.shape}")    # Print number of rows and columns for test set

# %%
train_df.head()
# Out:
#                                           Filename  Width  Height Name  xmin  \
# 3  132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   175
# 4  132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   227
# 5  142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    3   171
# 6  142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    0    40
# 7  142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    0   107
#
#    xmax  ymin  ymax  center_x  center_y         w         h
# 3   246     5    60  0.506010  0.078125  0.170673  0.132212
# 4   342    91   197  0.683894  0.346154  0.276442  0.254808
# 5   416     1    60  0.705529  0.073317  0.588942  0.141827
# 6    95     1    33  0.162260  0.040865  0.132212  0.076923
# 7   165     2    23  0.326923  0.030048  0.139423  0.050481

# %%
test_df.head()
# Out:
#                                            Filename  Width  Height Name  xmin  \
# 0   102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   188
# 1   102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   367
# 2   102_jpg.rf.bd045bdc3a950ed927cb2fca2cbe8b41.jpg    416     416    0   379
# 18  218_jpg.rf.2e758b47a34c68ee81d26379969a614f.jpg    416     416    0   116
# 27  281_jpg.rf.0891c6671bc9525ea47b7b2c77c4bb9f.jpg    416     416    0   252
#
#     xmax  ymin  ymax  center_x  center_y         w         h
# 0    234     4    28  0.507212  0.038462  0.110577  0.057692
# 1    416     4    27  0.941106  0.037260  0.117788  0.055288
# 2    417    49    88  0.956731  0.164663  0.091346  0.093750
# 18   168     8    37  0.341346  0.054087  0.125000  0.069712
# 27   299    29    56  0.662260  0.102163  0.112981  0.064904

# %%
len(train_filenames), len(test_filenames)
# Out:
# (51, 13)

# %% [markdown]
# Assign id Number to object name

# %%
def label_encoding(x):
    labels = {'0':183,'3':10,'1':9,'2':4,'4':1}
    return labels[x]

# %%
# Ensure that changes are applied to the actual DataFrame, not a view
train_df.loc[:, 'id'] = train_df['Name'].apply(label_encoding)
test_df.loc[:, 'id'] = test_df['Name'].apply(label_encoding)

# %%
train_df.head(10)
# Out:
#                                            Filename  Width  Height Name  xmin  \
# 3   132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   175
# 4   132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg    416     416    0   227
# 5   142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    3   171
# 6   142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    0    40
# 7   142_jpg.rf.fabfc1209c766563faadd4e9cf48f265.jpg    416     416    0   107
# 8   183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg    416     416    0   203
# 9   183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg    416     416    0   357
# 10  183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg    416     416    0   256
# 11  183_jpg.rf.dc58061295b4e680517a9c6e4c4ee558.jpg    416     416    1   282
# 12  202_jpg.rf.c4923ec1ed65f4757525e57f6fbdefa0.jpg    416     416    0   317
#
#     xmax  ymin  ymax  center_x  center_y         w         h   id
# 3    246     5    60  0.506010  0.078125  0.170673  0.132212  183
# 4    342    91   197  0.683894  0.346154  0.276442  0.254808  183
# 5    416     1    60  0.705529  0.073317  0.588942  0.141827   10
# 6     95     1    33  0.162260  0.040865  0.132212  0.076923  183
# 7    165     2    23  0.326923  0.030048  0.139423  0.050481  183
# 8    248    20    46  0.542067  0.079327  0.108173  0.062500  183
# 9    417   122   184  0.930288  0.367788  0.144231  0.149038  183
# 10   292     1    16  0.658654  0.020433  0.086538  0.036058  183
# 11   296    14    36  0.694712  0.060096  0.033654  0.052885    9
# 12   364    15    39  0.818510  0.064904  0.112981  0.057692  183

# %% [markdown]
# Save Image And Labels in Text

# %%
import os
from shutil import move

# %%
train_folder = 'data_images/train'
test_folder = 'data_images/test'


os.mkdir(train_folder)
os.mkdir(test_folder)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[129], line 5
#       1 train_folder = 'data_images/train'
#       2 test_folder = 'data_images/test'
# ----> 5 os.mkdir(train_folder)
#       6 os.mkdir(test_folder)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'data_images/train'

# %%
cols = ['Filename','id','center_x','center_y','w','h']
groupby_obj_train = train_df[cols].groupby('Filename')
groupby_obj_test = test_df[cols].groupby('Filename')

# %%
#groupby_obj_train.get_group('132_jpg.rf.d62de3ea40353dc0980dfd8f8ecc7299.jpg').set_index('Filename').to_csv('sample.txt',index=False,header=False)
#save each image in train and test folder andrespective labels in .txt
def save_data(Filename,folder_path, group_obj):
    #move Image
    src = os.path.join('data_images',Filename)
    dst = os.path.join(folder_path,Filename)
    move(src,dst) #move img from src to dst folder

    #save the labels
    text_filename = os.path.join(folder_path,
                                 os.path.splitext(Filename)[0]+'txt')
    group_obj.get_group(Filename).set_index('Filename').to_csv(text_filename,sep=' ',index=False,header=False) #remove commas and put separate space

# %%
#save .txt files along with images in train follder
filename_series = pd.Series(groupby_obj_train.groups.keys())

# %%
filename_series.apply(save_data,args=(train_folder,groupby_obj_train))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# 32    None
# 33    None
# 34    None
# 35    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 44    None
# 45    None
# 46    None
# 47    None
# 48    None
# 49    None
# 50    None
# dtype: object

# %%
#for test images
filename_series = pd.Series(groupby_obj_test.groups.keys())
filename_series.apply(save_data,args=(test_folder,groupby_obj_test))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# dtype: object
